# %%
library("rjags")
library("MASS")
data("OME")

dat = subset(OME, OME != "N/A")
dat$OME = factor(dat$OME) # relabel OME
dat$ID = as.numeric(factor(dat$ID)) # relabel ID so there are no gaps in numbers (they now go from 1 to 63)

## Original reference model and covariate matrix
mod_glm = glm(Correct/Trials ~ Age + OME + Loud + Noise, data=dat, weights=Trials, family="binomial")
X = model.matrix(mod_glm)[,-1]

## Original model (that needs to be extended)
mod_string = " model {
	for (i in 1:length(y)) {
		y[i] ~ dbin(phi[i], n[i])
		logit(phi[i]) = alpha[ID[i]] + b[1]*Age[i] + b[2]*OMElow[i] + b[3]*Loud[i] + b[4]*Noiseincoherent[i]
	}
	for (j in 1:4) {
		b[j] ~ dnorm(0.0, 1.0/4.0^2)
	}
    mu ~ dnorm(0.0, 1.0 / 10.0^2)
    tau2 ~ dgamma(1.0/2.0, 1.0/2.0)
    inv_tau2 = 1.0 / tau2
    for (j in 1:max(ID)) {
        alpha[j] ~ dnorm(mu, 1 / inv_tau2)
    }
} "

data_jags = as.list(as.data.frame(X))
data_jags$y = dat$Correct
data_jags$n = dat$Trials
data_jags$ID = dat$ID

params = c("b", "mu", "inv_tau2", "alpha")

mod = jags.model(textConnection(mod_string), data=data_jags, n.chains=3)
update(mod, 1e3)

mod_sim = coda.samples(model=mod,
                       variable.names=params,
                       n.iter=5e3)
mod_csim = as.mcmc(do.call(rbind, mod_sim))

## convergence diagnostics
plot(mod_sim)

gelman.diag(mod_sim)
autocorr.diag(mod_sim)
autocorr.plot(mod_sim)
effectiveSize(mod_sim)

## compute DIC
dic = dic.samples(mod, n.iter=1e3)
dic
# Out:
# Compiling model graph
#    Resolving undeclared variables
#    Allocating nodes
# Graph information:
#    Observed stochastic nodes: 712
#    Unobserved stochastic nodes: 69
#    Total graph size: 6500
#
# Initializing model
# Plot with title “Density of alpha[4]”
# Plot with title “Density of alpha[8]”
# Plot with title “Density of alpha[12]”
# Plot with title “Density of alpha[16]”
# Plot with title “Density of alpha[20]”
# Plot with title “Density of alpha[24]”
# Plot with title “Density of alpha[28]”
# Plot with title “Density of alpha[32]”
# Plot with title “Density of alpha[36]”
# Plot with title “Density of alpha[40]”
# Plot with title “Density of alpha[44]”
# Plot with title “Density of alpha[48]”
# Plot with title “Density of alpha[52]”
# Plot with title “Density of alpha[56]”
# Plot with title “Density of alpha[60]”
# Plot with title “Density of b[1]”
# Plot with title “Density of inv_tau2”
# Potential scale reduction factors:
#
#           Point est. Upper C.I.
# alpha[1]        1.25       1.70
# alpha[2]        1.25       1.70
# alpha[3]        1.24       1.68
# alpha[4]        1.28       1.78
# alpha[5]        1.26       1.74
# alpha[6]        1.22       1.63
# alpha[7]        1.27       1.76
# alpha[8]        1.24       1.67
# alpha[9]        1.23       1.64
# alpha[10]       1.26       1.73
# alpha[11]       1.26       1.74
# alpha[12]       1.23       1.64
# alpha[13]       1.23       1.66
# alpha[14]       1.24       1.67
# alpha[15]       1.24       1.69
# alpha[16]       1.23       1.64
# alpha[17]       1.23       1.64
# alpha[18]       1.25       1.71
# alpha[19]       1.23       1.64
# alpha[20]       1.26       1.73
# alpha[21]       1.23       1.65
# alpha[22]       1.27       1.76
# alpha[23]       1.22       1.63
# alpha[24]       1.27       1.76
# alpha[25]       1.26       1.74
# alpha[26]       1.23       1.66
# alpha[27]       1.24       1.68
# alpha[28]       1.25       1.70
# alpha[29]       1.23       1.66
# alpha[30]       1.22       1.64
# alpha[31]       1.24       1.68
# alpha[32]       1.23       1.65
# alpha[33]       1.24       1.67
# alpha[34]       1.22       1.63
# alpha[35]       1.23       1.64
# alpha[36]       1.22       1.62
# alpha[37]       1.24       1.69
# alpha[38]       1.23       1.66
# alpha[39]       1.23       1.66
# alpha[40]       1.22       1.62
# alpha[41]       1.21       1.61
# alpha[42]       1.23       1.65
# alpha[43]       1.23       1.67
# alpha[44]       1.23       1.66
# alpha[45]       1.24       1.67
# alpha[46]       1.22       1.62
# alpha[47]       1.23       1.64
# alpha[48]       1.24       1.66
# alpha[49]       1.24       1.67
# alpha[50]       1.24       1.68
# alpha[51]       1.22       1.63
# alpha[52]       1.22       1.63
# alpha[53]       1.24       1.68
# alpha[54]       1.24       1.66
# alpha[55]       1.22       1.62
# alpha[56]       1.24       1.67
# alpha[57]       1.24       1.68
# alpha[58]       1.26       1.72
# alpha[59]       1.22       1.62
# alpha[60]       1.22       1.64
# alpha[61]       1.23       1.65
# alpha[62]       1.23       1.64
# alpha[63]       1.25       1.71
# b[1]            1.05       1.15
# b[2]            1.02       1.08
# b[3]            1.25       1.73
# b[4]            1.02       1.06
# inv_tau2        1.01       1.02
# mu              1.33       1.95
#
# Multivariate psrf
#
# 1.19
#        alpha[1]  alpha[2]  alpha[3]  alpha[4]  alpha[5]  alpha[6]  alpha[7]
# Lag 0  1.0000000 1.0000000 1.0000000 1.0000000 1.0000000 1.0000000 1.0000000
# Lag 1  0.8230608 0.8379257 0.8123882 0.8771891 0.8469203 0.7650639 0.8417962
# Lag 5  0.7573401 0.7689609 0.7399689 0.8237636 0.7825343 0.6781914 0.7827031
# Lag 10 0.7387843 0.7504393 0.7134301 0.8005772 0.7597693 0.6590955 0.7646783
# Lag 50 0.6093502 0.6165249 0.5862885 0.6571032 0.6137381 0.5463238 0.6305047
#        alpha[8]  alpha[9]  alpha[10] ⋯ alpha[60] alpha[61] alpha[62] alpha[63]
# Lag 0  1.0000000 1.0000000 1.0000000 ⋯ 1.0000000 1.0000000 1.0000000 1.0000000
# Lag 1  0.8232603 0.7871194 0.8204483 ⋯ 0.8037096 0.7897499 0.7599135 0.8023540
# Lag 5  0.7501671 0.7002169 0.7497036 ⋯ 0.7209203 0.7035088 0.6692437 0.7254546
# Lag 10 0.7270746 0.6823289 0.7253563 ⋯ 0.6962800 0.6890921 0.6622445 0.7170684
# Lag 50 0.5990028 0.5619948 0.6052587 ⋯ 0.5883866 0.5761742 0.5459132 0.5893221
#        b[1]      b[2]       b[3]      b[4]       inv_tau2     mu
# Lag 0  1.0000000 1.00000000 1.0000000 1.00000000  1.000000000 1.0000000
# Lag 1  0.9458950 0.89510463 0.9838780 0.49903296  0.757046932 0.9894530
# Lag 5  0.7711244 0.59672570 0.9280563 0.08976513  0.360239907 0.9706354
# Lag 10 0.6089157 0.37783830 0.8692784 0.07632041  0.160566419 0.9484660
# Lag 50 0.1609764 0.05136921 0.6451047 0.05405050 -0.005170534 0.7891771
# Plot with title “Density of mu”
# Plot with title “alpha[9]”
# Plot with title “alpha[18]”
# Plot with title “alpha[27]”
# Plot with title “alpha[36]”
# Plot with title “alpha[45]”
# Plot with title “alpha[54]”
# Plot with title “alpha[63]”
# Plot with title “alpha[3]”
# Plot with title “alpha[12]”
# Plot with title “alpha[21]”
# Plot with title “alpha[30]”
# Plot with title “alpha[39]”
# Plot with title “alpha[48]”
# Plot with title “alpha[57]”
# Plot with title “b[3]”
# Plot with title “alpha[6]”
# Plot with title “alpha[15]”
# Plot with title “alpha[24]”
# Plot with title “alpha[33]”
# Plot with title “alpha[42]”
# Plot with title “alpha[51]”
# Plot with title “alpha[60]”
#   alpha[1]   alpha[2]   alpha[3]   alpha[4]   alpha[5]   alpha[6]   alpha[7]
#   56.23877   58.05517   70.86165   51.45066   60.45055   68.51718   52.62987
#   alpha[8]   alpha[9]  alpha[10]  alpha[11]  alpha[12]  alpha[13]  alpha[14]
#   69.43311   60.72187   60.71210   55.04029   70.75426   66.75505   60.86785
#  alpha[15]  alpha[16]  alpha[17]  alpha[18]  alpha[19]  alpha[20]  alpha[21]
#   62.04085   59.54117   65.81357   64.35442   71.05914   54.04160   67.71563
#  alpha[22]  alpha[23]  alpha[24]  alpha[25]  alpha[26]  alpha[27]  alpha[28]
#   56.24783   67.08305   63.55515   52.43978   65.05460   68.07189   54.25888
#  alpha[29]  alpha[30]  alpha[31]  alpha[32]  alpha[33]  alpha[34]  alpha[35]
#   66.37316   59.29302   67.42701   81.39696   72.31243   64.49642   66.63319
#  alpha[36]  alpha[37]  alpha[38]  alpha[39]  alpha[40]  alpha[41]  alpha[42]
#   64.32343   64.00311   54.65926   65.47601   63.60877   79.24222   65.78239
#  alpha[43]  alpha[44]  alpha[45]  alpha[46]  alpha[47]  alpha[48]  alpha[49]
#   63.28125   64.72205   67.30403   61.94278   64.70921   60.47811   62.81691
#  alpha[50]  alpha[51]  alpha[52]  alpha[53]  alpha[54]  alpha[55]  alpha[56]
#   61.12642   52.86659   75.42851   67.49937   61.43549   71.08423   56.91881
#  alpha[57]  alpha[58]  alpha[59]  alpha[60]  alpha[61]  alpha[62]  alpha[63]
#   51.71594   55.51462   70.07163   57.40420   64.34723   68.05708   69.20828
#       b[1]       b[2]       b[3]       b[4]   inv_tau2         mu
#  387.12741  783.94688  108.89748 2225.72771 1570.22990   36.93427
# Mean deviance:  1241
# penalty 28.92
# Penalized deviance: 1270
# Plot with title “mu”
